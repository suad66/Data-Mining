# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.linear_model import LinearRegression,Lasso
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.ensemble import RandomForestRegressor
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

dataTrain = pd.read_csv('laptop_data.csv')

dataTrain.head()
# Out:
#    Inches   TypeName Company ScreenResolution                         Cpu  \
# 0    13.3  Ultrabook   Apple        2560x1600        Intel Core i5 2.3GHz
# 1    13.3  Ultrabook   Apple         1440x900        Intel Core i5 1.8GHz
# 2    15.6   Notebook      HP        1920x1080  Intel Core i5 7200U 2.5GHz
# 3    15.4  Ultrabook   Apple        2880x1800        Intel Core i7 2.7GHz
# 4    13.3  Ultrabook   Apple        2560x1600        Intel Core i5 3.1GHz
#
#    Ram  Memory   Gpu  OpSys  Weight        Price
# 0    8     128   640  macOS    1.37   71378.6832
# 1    8     128  6000  macOS    1.34   47895.5232
# 2    8     256   620  No OS    1.86   30636.0000
# 3   16     512   455  macOS    1.83  135195.3360
# 4    8     256   650  macOS    1.37   96095.8080

# %%
type(dataTrain)
# Out:
# pandas.core.frame.DataFrame

# %%
dataTrain.shape
# Out:
# (1303, 11)

# %%
dataTrain = dataTrain.dropna()

# %%
dataTrain.isnull().sum()
# Out:
# Inches              0
# TypeName            0
# Company             0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
dataTrain.shape
# Out:
# (1303, 11)

# %%
dataTrain.dtypes
# Out:
# Inches              float64
# TypeName             object
# Company              object
# ScreenResolution     object
# Cpu                  object
# Ram                   int64
# Memory                int64
# Gpu                   int64
# OpSys                object
# Weight              float64
# Price               float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
corr = dataTrain.corr()

sns.heatmap(corr,annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       2 import seaborn as sns
#       4 plt.figure(figsize=(10,6))
# ----> 5 corr = dataTrain.corr()
#       7 sns.heatmap(corr,annot=True)
#       8 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:10704, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10702 cols = data.columns
#   10703 idx = cols.copy()
# > 10704 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10706 if method == "pearson":
#   10707     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1889, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1887 if dtype is not None:
#    1888     dtype = np.dtype(dtype)
# -> 1889 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1890 if result.dtype is not dtype:
#    1891     result = np.array(result, dtype=dtype, copy=False)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.as_array(self, dtype, copy, na_value)
#    1654         arr.flags.writeable = False
#    1655 else:
# -> 1656     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1657     # The underlying data was copied within _interleave, so no need
#    1658     # to further copy if copy=True or setting na_value
#    1660 if na_value is lib.no_default:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:1715, in BlockManager._interleave(self, dtype, na_value)
#    1713     else:
#    1714         arr = blk.get_values(dtype)
# -> 1715     result[rl.indexer] = arr
#    1716     itemmask[rl.indexer] = 1
#    1718 if not itemmask.all():
#
# ValueError: could not convert string to float: 'Ultrabook'

# %%
dataTrain.describe()
# Out:
#             Inches          Ram       Memory          Gpu       Weight  \
# count  1303.000000  1303.000000  1303.000000  1303.000000  1303.000000
# mean     15.009056     8.382195   226.215656   695.855718     2.038734
# std       1.452957     5.084665   174.438239   546.915086     0.665475
# min       5.000000     2.000000     1.000000     0.000000     0.690000
# 25%      14.000000     4.000000    64.000000   520.000000     1.500000
# 50%      15.600000     8.000000   256.000000   620.000000     2.040000
# 75%      15.600000     8.000000   256.000000   930.000000     2.300000
# max      18.400000    64.000000   517.000000  6150.000000     4.700000
#
#                Price
# count    1303.000000
# mean    59870.042910
# std     37243.201786
# min      9270.720000
# 25%     31914.720000
# 50%     52054.560000
# 75%     79274.246400
# max    324954.720000

# %%
dataTrain.loc[dataTrain['Price'] == 1, 'Price'] = 500

# %%
dataTrain.describe()
# Out:
#             Inches          Ram       Memory          Gpu       Weight  \
# count  1303.000000  1303.000000  1303.000000  1303.000000  1303.000000
# mean     15.009056     8.382195   226.215656   695.855718     2.038734
# std       1.452957     5.084665   174.438239   546.915086     0.665475
# min       5.000000     2.000000     1.000000     0.000000     0.690000
# 25%      14.000000     4.000000    64.000000   520.000000     1.500000
# 50%      15.600000     8.000000   256.000000   620.000000     2.040000
# 75%      15.600000     8.000000   256.000000   930.000000     2.300000
# max      18.400000    64.000000   517.000000  6150.000000     4.700000
#
#                Price
# count    1303.000000
# mean    59870.042910
# std     37243.201786
# min      9270.720000
# 25%     31914.720000
# 50%     52054.560000
# 75%     79274.246400
# max    324954.720000

# %%
import matplotlib.pyplot as plt

dataTrain['Price'].plot(kind = 'hist', bins = 5, edgecolor='black')   # 5 bins are used
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Prices')
plt.show()

# %%
dataTrain.describe(include = 'object')
# Out:
#         TypeName Company ScreenResolution                         Cpu  \
# count       1303    1303             1303                        1303
# unique         6      19               33                         118
# top     Notebook    Dell        1920x1080  Intel Core i5 7200U 2.5GHz
# freq         727     297              507                         190
#
#              OpSys
# count         1303
# unique           9
# top     Windows 10
# freq          1072

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.regplot(x="Inches", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['Inches'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.06521969504455838  with a P-value of P = 0.018548200171502726

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="Ram", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Ram', ylabel='Price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['Ram'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.743007135250695  with a P-value of P = 3.9103435619843916e-229

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="Memory", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Memory', ylabel='Price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['Memory'], dataTrain['Price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.2966008010776523  with a P-value of P = 7.152552722783012e-28

# %%
sns.boxplot(x="TypeName", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='TypeName', ylabel='Price'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="Company", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Company', ylabel='Price'>

# %%
sns.boxplot(x="ScreenResolution", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='ScreenResolution', ylabel='Price'>

# %%
sns.boxplot(x="Cpu", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='Cpu', ylabel='Price'>

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="OpSys", y="Price", data=dataTrain)
# Out:
# <Axes: xlabel='OpSys', ylabel='Price'>

# %%
dataTrain.drop(['Cpu'], axis = 1, inplace = True)

# %%
dataTrain.shape
# Out:
# (1303, 10)

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
dataTrain.Inches = labelencoder.fit_transform(dataTrain.Inches)
dataTrain.TypeName = labelencoder.fit_transform(dataTrain.TypeName)
dataTrain.Company = labelencoder.fit_transform(dataTrain.Company)
dataTrain.ScreenResolution = labelencoder.fit_transform(dataTrain.ScreenResolution)

dataTrain.Ram = labelencoder.fit_transform(dataTrain.Ram)
dataTrain.Memory = labelencoder.fit_transform(dataTrain.Memory)
dataTrain.Gpu = labelencoder.fit_transform(dataTrain.Gpu)
dataTrain.OpSys = labelencoder.fit_transform(dataTrain.OpSys)
dataTrain.Weight = labelencoder.fit_transform(dataTrain.Weight)

# %%
dataTrain.head(10)
# Out:
#    Inches  TypeName  Company  ScreenResolution  Ram  Memory  Gpu  OpSys  \
# 0       8         4        1                21    3       6   39      8
# 1       8         4        1                26    3       6   61      8
# 2      15         3        7                28    3       9   37      4
# 3      14         4        1                22    5      12   22      8
# 4       8         4        1                21    3       9   40      8
# 5      15         3        0                25    1      10    4      5
# 6      14         4        1                31    5       9    0      3
# 7       8         4        1                26    3       9   61      8
# 8      11         4        2                17    5      12    9      5
# 9      11         4        0                17    3       9   37      5
#
#    Weight        Price
# 0      37   71378.6832
# 1      34   47895.5232
# 2      72   30636.0000
# 3      69  135195.3360
# 4      37   96095.8080
# 5      93   21312.0000
# 6      87  114017.6016
# 7      34   61735.5360
# 8      31   79653.6000
# 9      55   41025.6000

# %%
import scipy.stats as stats
dataTrain = stats.zscore(dataTrain)

# %%
dataTrain
# Out:
#         Inches  TypeName   Company  ScreenResolution       Ram    Memory  \
# 0    -1.362940  1.138779 -1.333189          0.634655  0.183436 -0.229199
# 1    -1.362940  1.138779 -1.333189          1.269310  0.183436 -0.229199
# 2     0.557557  0.335406  0.136477          1.523172  0.183436  0.529428
# 3     0.283200  1.138779 -1.333189          0.761586  1.549245  1.288054
# 4    -1.362940  1.138779 -1.333189          0.634655  0.183436  0.529428
# ...        ...       ...       ...               ...       ...       ...
# 1298 -0.539870 -2.074710  0.871310          1.523172 -1.182374 -0.229199
# 1299 -1.362940 -2.074710  0.871310          2.030896  1.549245  1.288054
# 1300 -0.539870  0.335406  0.871310          1.142379 -1.865278 -0.482074
# 1301  0.557557  0.335406  0.136477          1.142379 -0.499469 -1.746451
# 1302  0.557557  0.335406 -1.088245          1.142379 -1.182374  0.782303
#
#            Gpu     OpSys    Weight     Price
# 0     0.390826  3.083616 -1.143311  0.309132
# 1     2.109144  3.083616 -1.218146 -0.321646
# 2     0.234616 -0.781657 -0.270240 -0.785251
# 3    -0.936964  3.083616 -0.345074  2.023301
# 4     0.468932  3.083616 -1.143311  0.973055
# ...        ...       ...       ...       ...
# 1298 -0.390227  0.184661 -0.370019 -0.695089
# 1299 -0.390227  0.184661 -1.292981  0.537128
# 1300 -2.655282  0.184661 -0.843973 -1.280428
# 1301 -1.718018  0.184661  0.428218 -0.514765
# 1302 -2.655282  0.184661  0.478108 -1.080067
#
# [1303 rows x 10 columns]

# %%
x_train=dataTrain.iloc[:,0:8]
y_train=dataTrain.iloc[:,9]

# %%
x_train.head()
# Out:
#      Inches  TypeName   Company  ScreenResolution       Ram    Memory  \
# 0 -1.362940  1.138779 -1.333189          0.634655  0.183436 -0.229199
# 1 -1.362940  1.138779 -1.333189          1.269310  0.183436 -0.229199
# 2  0.557557  0.335406  0.136477          1.523172  0.183436  0.529428
# 3  0.283200  1.138779 -1.333189          0.761586  1.549245  1.288054
# 4 -1.362940  1.138779 -1.333189          0.634655  0.183436  0.529428
#
#         Gpu     OpSys
# 0  0.390826  3.083616
# 1  2.109144  3.083616
# 2  0.234616 -0.781657
# 3 -0.936964  3.083616
# 4  0.468932  3.083616

# %%
y_train.head()
# Out:
# 0    0.309132
# 1   -0.321646
# 2   -0.785251
# 3    2.023301
# 4    0.973055
# Name: Price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model_mlr = model.fit(x_train,y_train)

# %%
y_pred1 = model_mlr.predict(x_train)

# %%
y_train[0]
# Out:
# 0.3091318278251069

# %%
y_pred1[0]
# Out:
# 0.5729136845672941

# %%
mse1 = mean_squared_error(y_train, y_pred1)
print('The mean square error for Multiple Linear Regression: ', mse1)
# Out:
# The mean square error for Multiple Linear Regression:  0.36390304241212845

# %%
mae1= mean_absolute_error(y_train, y_pred1)
print('The mean absolute error for Multiple Linear Regression: ', mae1)
# Out:
# The mean absolute error for Multiple Linear Regression:  0.43246183204635

# %%
rf = RandomForestRegressor()
model_rf = rf.fit(x_train,y_train)

# %%
y_pred2 = model_rf.predict(x_train)

# %%
mse2 = mean_squared_error(y_train, y_pred2)
print('The mean square error of price and predicted value is: ', mse2)
# Out:
# The mean square error of price and predicted value is:  0.03935405804193683

# %%
mae2= mean_absolute_error(y_train, y_pred2)
print('The mean absolute error of price and predicted value is: ', mae2)
# Out:
# The mean absolute error of price and predicted value is:  0.12554316995101422

# %%
LassoModel = Lasso()
model_lm = LassoModel.fit(x_train,y_train)

# %%
y_pred3 = model_lm.predict(x_train)

# %%
mae3= mean_absolute_error(y_train, y_pred3)
print('The mean absolute error of price and predicted value is: ', mae3)
# Out:
# The mean absolute error of price and predicted value is:  0.7655069186730763

# %%
mse3 = mean_squared_error(y_train, y_pred3)
print('The mean square error of price and predicted value is: ', mse3)
# Out:
# The mean square error of price and predicted value is:  1.0

# %%
scores = [('MLR', mae1),
          ('Random Forest', mae2),
          ('LASSO', mae3)
         ]

# %%
mae = pd.DataFrame(data = scores, columns=['Model', 'MAE Score'])
mae
# Out:
#            Model  MAE Score
# 0            MLR   0.432462
# 1  Random Forest   0.125543
# 2          LASSO   0.765507

# %%
mae.sort_values(by=(['MAE Score']), ascending=False, inplace=True)

f, axe = plt.subplots(1,1, figsize=(10,7))
sns.barplot(x = mae['Model'], y=mae['MAE Score'], ax = axe)
axe.set_xlabel('Model', size=20)
axe.set_ylabel('Mean Absolute Error', size=20)
# Out:
# Text(0, 0.5, 'Mean Absolute Error')
